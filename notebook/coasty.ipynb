# %% [markdown]
# <img src="../assets/header.gif" style="width:100%">
# <hr style="color:#808080;">
# <p align="center"><b>C O A S T Y</b></p>
# <hr style="color:#808080;">

# %% [markdown]
# **Figure**: Spatial distribution of hypoxic profiles over the global coastal ocean over the
# whole data period (1950-now) and per decade.

# %%
# %run scripts/figure-1.py
