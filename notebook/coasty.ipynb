# %% [markdown]
# <img src="../assets/header.gif" style="width:100%">
# <hr style="color:#808080;">
# <p align="center"><b>C O A S T Y</b></p>
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 1** — Spatial distribution of hypoxic profiles over the global coastal ocean (1950–present and per decade).

# %%
# %run scripts/figure-1.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 2** — Spatial distribution of hypoxic profiles (1950–present + per decade) with Diaz & Rosenberg (2008) historical hypoxic zones superimposed.

# %%
# %run scripts/figure-2.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 3** — Annual time series of hypoxic site count and mean hypoxic percentage (1950–present) with 10-year rolling mean.

# %%
# %run scripts/figure-3.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 4** — Climatological seasonal cycle of hypoxic sites, split by hemisphere (Northern vs. Southern).

# %%
# %run scripts/figure-4.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 5** — 2-D heatmap of hypoxic site count and mean hypoxic percentage on a 5°×5° global grid.

# %%
# %run scripts/figure-5.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 6** — Distribution of bottom dissolved oxygen over three representative decades (1960s, 1980s, 2010s) — KDE and global maps.

# %%
# %run scripts/figure-6.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 7** — Sampling effort — spatial distribution of profiles per site (1950–present and per decade).

# %%
# %run scripts/figure-7.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 8** — Sampling effort — annual profile count by instrument type (water bottle, Argo, CTD) with cumulative line.

# %%
# %run scripts/figure-8.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 9** — Sampling effort — latitudinal histogram, longitudinal histogram, and 2-D profile density heatmap.

# %%
# %run scripts/figure-9.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 10** — Sampling effort — seasonal (monthly) profile count by instrument type.

# %%
# %run scripts/figure-10.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 11** — Aggregation analysis — seasonal coverage fraction for combinations of spatial (5/15/50 km) and temporal (5/10 yr) bin sizes.

# %%
# %run scripts/figure-11.py

# %% [markdown]
# <hr style="color:#808080;">

# %% [markdown]
# **Figure 12** — Sampling intensity classification — sites categorized as Episodic/Irregular/Moderate/Intense (profiles per decade).

# %%
# %run scripts/figure-12.py
