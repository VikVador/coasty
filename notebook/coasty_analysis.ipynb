# %% [markdown]
# ## Diagnostics
#
# In this notebook we show oxygen indicators on the global coastal ocean. Unless explicitly told otherwise, all the metrics are computed on bins of size 50 km x 50 km.
#
# **Possible issue:** We selected only profiles with at least a data point at less than 15m from the bottom, but we don't do any check for datapoints collected in the proximity of the surface. This may underestimate the oxygen in the water column, since surface tends to be more oxygenated. However, the profiles with no data point in the first 15 m are around 1%, so hopefully the results are not too much affected.

# %% [markdown]
# **Figure 1** — Vertically averaged oxygen inventory of the global coastal zone

# %%
# %run scripts/analysis/figure-1.py
# Out:
# Loading dataset...
#   Profiles: 327,316
# Computing vertically averaged oxygen inventory...
#   Profiles with valid vertically averaged O2: 327,316 / 327,316
#
# Aggregating all data spatially...
#   Total sites: 12,005 | Hypoxic sites: 26
#
# Generating decadal maps...
#   1950s: 11,971 profiles | 2,243 sites | 2 hypoxic sites
#   1960s: 33,131 profiles | 5,696 sites | 16 hypoxic sites
#   1970s: 50,275 profiles | 5,602 sites | 9 hypoxic sites
#   1980s: 49,457 profiles | 4,402 sites | 10 hypoxic sites
#   1990s: 75,592 profiles | 3,666 sites | 6 hypoxic sites
#   2000s: 65,387 profiles | 2,622 sites | 49 hypoxic sites
#   2010s: 33,172 profiles | 2,182 sites | 24 hypoxic sites
#   2020s: 8,331 profiles | 985 sites | 8 hypoxic sites
# Figures saved to /gpfs/home/acad/ulg-mast/fadobbat/coasty/plots/analysis/figure-1/

# %% [markdown]
# **Figure 2** - Thickness of the bottom hypoxic layer. Select the bottom-hypoxic profiles, look for the first non-hypoxic observation from the bottom and compute how many meters between these 2 observations are hypoxic.
# The plot shows only sites where hypoxic layer is greater than 0.

# %%
# %run scripts/analysis/figure-2.py
# Out:
# Loading dataset...
#   Profiles: 327,316
# Computing bottom hypoxic layer thickness...
#   Profiles with hypoxic layer: 32,984 / 327,316
#
# Aggregating all data spatially...
#   Total sites with hypoxic layer: 1,290
#
# Generating decadal maps...
#   1950s: 515 profiles | 166 sites with hypoxic layer
#   1960s: 3,278 profiles | 499 sites with hypoxic layer
#   1970s: 3,963 profiles | 497 sites with hypoxic layer
#   1980s: 4,149 profiles | 354 sites with hypoxic layer
#   1990s: 6,544 profiles | 483 sites with hypoxic layer
#   2000s: 8,645 profiles | 468 sites with hypoxic layer
#   2010s: 4,514 profiles | 339 sites with hypoxic layer
#   2020s: 1,376 profiles | 129 sites with hypoxic layer
# Figures saved to /gpfs/home/acad/ulg-mast/fadobbat/coasty/plots/analysis/figure-2/

# %% [markdown]
# **Figure 3** - pO2 (biological indicator) - computed at the surface (only?)
